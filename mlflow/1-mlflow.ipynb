# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.get_experiment_by_name("check localhost connection")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/651749145469881263', creation_time=1761372910951, experiment_id='651749145469881263', last_update_time=1761372910951, lifecycle_stage='active', name='check localhost connection', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %%
mlflow.set_experiment("check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Sachi",1)
# Out:
# 🏃 View run capricious-calf-589 at: http://127.0.0.1:5000/#/experiments/651749145469881263/runs/27bcf346ed164df8bfb95e3886d2ae7c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/651749145469881263

# %%
with mlflow.start_run():
    mlflow.log_metric("test",2)
    mlflow.log_metric("Sachi",2)
# Out:
# 🏃 View run mysterious-perch-77 at: http://127.0.0.1:5000/#/experiments/651749145469881263/runs/304f8dcc6d0b4661a550bd0b014dfb42
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/651749145469881263

# %%
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
### set tracking uri
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# %%
X,y=datasets.load_iris(return_X_y=True)
## split the data in traininng and tst
X_train,X_text,y_train,y_test=train_test_split(X,y,test_size=0.2)

### Define the model hyperparameter
params={"penalty":"l2","solver":"lbfgs","max_iter":1000,"multi_class":"auto","random_state":8888}

lr=LogisticRegression(**params)
lr.fit(X_train,y_train)
# Out:
# /home/sachchida/anaconda3/envs/torch-cuda12_8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
### Prediction on test data
y_pred=lr.predict(X_text)
y_pred
# Out:
# array([2, 0, 0, 2, 2, 0, 0, 0, 1, 2, 2, 1, 1, 1, 0, 1, 2, 0, 1, 2, 2, 1,
#        0, 1, 0, 1, 2, 0, 2, 2])

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9666666666666667

# %%
### MLFlow tracking
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

### Create a new MLFlow experiment
mlflow.set_experiment("MLFLOW Quickstart")

## start an mlflow run
with mlflow.start_run():
    ### log the hyperparameter
    mlflow.log_params(params)

    ### Log the accuraccy matrix
    mlflow.log_metric("accuracy",accuracy)
    ## set tags that we can use to remind ourselfs what this run was for
    mlflow.set_tag("Training info","Basic LR model for IRIS data")

    ### infer the model signature
    ### signature represents model input and output as data frames with optionally named columns and data type specified as one of types in defined in mlflow.types.Datatype
    ### It also includes parameters scheama for inference. This mehtod will raise and exception if the data contains incompatible types 
    signature=infer_signature(X_train,lr.predict(X_train))

    ## Log the model
    model_info=mlflow.sklearn.log_model(sk_model=lr,artifact_path="iris_model",
                                        signature=signature,input_example=X_train,
                                        registered_model_name="tracking-quickstart")
# Out:
# 2025/10/25 12:35:52 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Registered model 'tracking-quickstart' already exists. Creating a new version of this model...
# 2025/10/25 12:35:52 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 3
# 🏃 View run defiant-gnu-280 at: http://127.0.0.1:5000/#/experiments/744891344091760063/runs/3e90f8522431426fa74a0a11590fbc1f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/744891344091760063
# Created version '3' of model 'tracking-quickstart'.

# %%
X,y=datasets.load_iris(return_X_y=True)
## split the data in traininng and tst
X_train,X_text,y_train,y_test=train_test_split(X,y,test_size=0.2)

### Define the model hyperparameter
params={"penalty":"l2","solver":"newton-cg","max_iter":1000,"multi_class":"auto","random_state":8888}

lr=LogisticRegression(**params)
lr.fit(X_train,y_train)
# Out:
# /home/sachchida/anaconda3/envs/torch-cuda12_8/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888,
#                    solver='newton-cg')

# %%
### MLFlow tracking
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

### Create a new MLFlow experiment
mlflow.set_experiment("MLFLOW Quickstart")

## start an mlflow run
with mlflow.start_run():
    ### log the hyperparameter
    mlflow.log_params(params)

    ### Log the accuraccy matrix
    mlflow.log_metric("accuracy",accuracy)
    ## set tags that we can use to remind ourselfs what this run was for
    mlflow.set_tag("Training info","Basic LR model for IRIS data")

    ### infer the model signature
    ### signature represents model input and output as data frames with optionally named columns and data type specified as one of types in defined in mlflow.types.Datatype
    ### It also includes parameters scheama for inference. This mehtod will raise and exception if the data contains incompatible types 
    signature=infer_signature(X_train,lr.predict(X_train))

    ## Log the model
    model_info=mlflow.sklearn.log_model(sk_model=lr,artifact_path="iris_model",
                                        signature=signature,input_example=X_train,
                                        registered_model_name="tracking-quickstart")
# Out:
# 2025/10/25 12:35:53 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Registered model 'tracking-quickstart' already exists. Creating a new version of this model...
# 2025/10/25 12:35:53 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 4
# 🏃 View run delightful-zebra-193 at: http://127.0.0.1:5000/#/experiments/744891344091760063/runs/0f22f7c6dd5d4d77a5925ab0331a18ef
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/744891344091760063
# Created version '4' of model 'tracking-quickstart'.

# %%
model_info.model_uri
# Out:
# 'models:/m-8dc28c78a7ff4bd9a93890039d29be3b'

# %% [markdown]
# #### Load the entire model in generic python function model

# %%
loaded_model=mlflow.pyfunc.load_model(model_info.model_uri)

# %%
predictions=loaded_model.predict(X_text)
iris_features_name=datasets.load_iris().feature_names
result=pd.DataFrame(X_text,columns=iris_features_name)

# %%
result["acutal_class"]=y_test
result["predicted_class"]=predictions
result
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.9               3.0                5.1               1.8
# 1                 7.6               3.0                6.6               2.1
# 2                 4.8               3.1                1.6               0.2
# 3                 6.6               2.9                4.6               1.3
# 4                 4.4               3.0                1.3               0.2
# 5                 5.1               3.8                1.5               0.3
# 6                 6.1               2.9                4.7               1.4
# 7                 5.7               2.5                5.0               2.0
# 8                 4.7               3.2                1.3               0.2
# 9                 6.7               3.1                5.6               2.4
# 10                6.1               2.6                5.6               1.4
# ...
